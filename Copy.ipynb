# %% [markdown]
# This document is for testing some quick simple ITK tutorials
#  $\int_a^b f(x) dx$

# %%
import SimpleITK as sitk
import myshow as ms
img1 = sitk.ReadImage("Data/cthead1.png")

img2=sitk.ReadImage('/Users/tmstou)

# %%
ms.myshow(img1)

# %%
gf=sitk.SmoothingRecursiveGaussian(img1,5.0)
ms.myshow(gf)

# %%
# Out:
#   File "<ipython-input-4-c3d2ada350b6>", line 1
#     sitk.convert Copy.ipynb Copy.pdf
#                     ^
# SyntaxError: invalid syntax
